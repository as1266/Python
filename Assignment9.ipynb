# %% [markdown]
# <a href="https://colab.research.google.com/github/as1266/Python/blob/master/Assignment9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Mytime():
    def __init__(self, hrs=0, mins=0, secs=0):
        totalsecs = hrs * 3600 + mins * 60 + secs
        self.hours = totalsecs // 3600
        leftoversecs = totalsecs % 3600
        self.minutes = leftoversecs // 60
        self.seconds = leftoversecs % 60

    def increment(self, seconds):
        self.seconds += seconds
        while self.seconds >= 60:
            self.seconds -= 60
            self.minutes += 1

        while self.minutes >= 60:
            self.minutes -= 60
            self.hours += 1

    def to_seconds(self):
        return self.hours * 3600 + self.minutes * 60 + self.seconds

    def __add__(self, other):
        return Mytime(0, 0, self.to_seconds() + other.to_seconds())

    def __str__(self):
        return "the time is {0}:{1}:{2}".format(self.hours, self.minutes, self.seconds)

    def comparetime(self, timeInstance):
        hoursInMinutes = (time1.hours - timeInstance.hours) * 60
        minutes = (time1.minutes - timeInstance.minutes)
        secondsinMinutes = (time1.seconds - timeInstance.seconds) / 60
        totalDiff = hoursInMinutes + minutes + secondsinMinutes
        return totalDiff


def add_time(t1, t2):
    h = t1.hours + t2.hours
    m = t1.minutes + t2.minutes
    s = t1.seconds + t2.seconds

    if s >= 60:
        s -= 60
        m += 1

    if m >= 60:
        m -= 60
        h += 1

    sum_t = Mytime(h, m, s)
    return sum_t


time1 = Mytime(11, 20, 43)
time2 = Mytime(10, 20, 30)

print("The interval minutes are about:", time1.comparetime(time2))

# %%
class Card:
    suits = ["Clubs", "Diamonds", "Hearts", "Spades"]
    ranks = ["narf", "Ace", "2", "3", "4", "5", "6", "7", "8", "9", "10", "Jack", "Queen", "King"]

    def __init__(self, suit=0, rank=0):
        self.suit = suit
        self.rank = rank

    def __str__(self):
        return (self.ranks[self.rank] + " of " + self.suits[self.suit])

    def cmp(self, other):
        if self.suit > other.suit: return 1
        if self.suit < other.suit: return -1

        if self.rank > other.rank:
            if self.rank == 13 and other.rank == 1:
                return -1
            else:
                return 1
        if self.rank < other.rank:
            if self.rank == 1 and other.rank == 13:
                return 1
            else:
                return -1

        return 0

    def __eq__(self, other):
        return self.cmp(other) == 0

    def __le__(self, other):
        return self.cmp(other) <= 0

    def __ge__(self, other):
        return self.cmp(other) >= 0

    def __gt__(self, other):
        return self.cmp(other) > 0

    def __lt__(self, other):
        return self.cmp(other) < 0

    def __ne__(self, other):
        return self.cmp(other) != 0


card1 = Card(1, 1)
print("Card1 :",card1)

card2 = Card(1, 13)
print("Card2 :",card2)

print(card1 > card2)

# %%
def readposint():
    userInput=int(input("Please input a int number: "))
    if userInput<0:
        myerror=ValueError("{0} is not a valid age".format(userInput))
        raise myerror
    return userInput
try:
    print(readposint())
except ValueError:
    userIn = int(input("Input is valid, please input a positive int number:"))
    if userIn< 0:
        myerror = ValueError("{0} is not a positive number".format(userIn))
        raise myerror
